# %% [markdown]
# ## Python Intermediate

# %% [markdown]
# - #### "Classes and Objects Tutorial" playlist - Tech with Tim, cool youtube channel / ton of usefull stuff with very explicit explanation and understandable examples / - https://www.youtube.com/watch?v=v_Jp11xqCzg&list=PLzMcBGfZo4-l1MqB1zoYfqzlj_HH-

# %% [markdown]
# - #### "Python Data Structures and Algorithms" - Game-based course on Linkedin with code chellenges and quizes / looks fun / - https://learn.epam.com/detailsPage?id=7bd2b04f-3d56-41ab-bea3-764ae4a47915 or https://www.linkedin.com/learning/python-data-structures-and-algorithms/python-data-structures-and-algorithms-in-action?dApp=53239054&leis=LAA&u=2113185

# %% [markdown]
# ## ML classic

# %% [markdown]
# - #### "Machine Learning for Beginners" playlist - Express course to regression models from Microsoft presented by Bea Stollnitz / short but dense videos with engaging examples and inspirational presentation / - https://www.youtube.com/watch?v=6mSx_KJxcHI&list=PLlrxD0HtieHjNnGcZ1TWzPjKYWgfXSiWG&index=1

# %% [markdown]
# - #### "Supervised Machine Learning: Regression and Classification" - absolutly must watch classic Andrew Ng course in colabaration with DeepLearning.AI / if you really want to understand how ML works / - https://www.coursera.org/learn/machine-learning?specialization=machine-learning-introduction

# %% [markdown]
# ### Deeper into NLP

# %% [markdown]
# - #### "NLP Course | For You" by Lena Voita / great place to study NLP, lots of topics covered, from word embeddings to Neural Networks / - https://lena-voita.github.io/nlp_course.html

# %% [markdown]
# ### Deep Learning (advanced topic warning)

# %% [markdown]
# - #### "The Book" - https://www.bishopbook.com/

# %% [markdown]
# PS: Some slides I stole from AWS learning materials :D Just for a bit of visual clarification.

# %% [markdown]
# ![ds.png](attachment:ds.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![data.png](attachment:data.png)

# %% [markdown]
# ![data_quality.png](attachment:data_quality.png)
