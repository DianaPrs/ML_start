# %% [markdown]
# ### What is Machine Learning?

# %%
"Fitting a function to examples and using that function to generalize and make predictions about new examples." # Derek Jedamski

# %% [markdown]
# ![ML_base.jpg](attachment:47a02d92-453c-48f9-9df1-e51571d6c1d9.jpg)

# %% [markdown]
# # Required tools

# %% [markdown]
# ### NumPy Essential Training: 1 Foundations of NumPy

# %% [markdown]
# https://learn.epam.com/detailsPage?id=161a2305-c118-44f3-8a79-499c078bc40d

# %% [markdown]
# * Anaconda
# * Jupyter Notebook
# * NumPy

# %% [markdown]
# ### Good to start familiarization

# %% [markdown]
# * pandas
# https://www.kaggle.com/learn/pandas
#
#
# * matplotlib
# https://matplotlib.org/ https://cs231n.github.io/python-numpy-tutorial/#matplotlib
#
# * google colaboratory
# https://colab.research.google.com/

# %% [markdown]
# ### Advanced topics (math and statistics)
# #### (Derivatives, Integrals, Vectors, Matrix Operations, Probability Theory)

# %% [markdown]
# Self-study materials: [Math for Data Science](https://training.epam.com/en/blog/555)
#
# 🎲 Bite-sized videos: [The Essence of Probability](https://www.youtube.com/playlist?list=PLiAulSm0XXgvCGe63mrAkda9UQ9478YQv) 🎲
#
# Book in pdf: [The Elements of Statistical Learning](https://www.sas.upenn.edu/~fdiebold/NoHesitations/BookAdvanced.pdf)

# %% [markdown]
# ### [💥🚀💥 Stanford Uni Lecture Collection free on youtube 🔥❤️🔥](https://www.youtube.com/@stanfordonline)
#
# * machine learning (CS229)
# * natural language processing (CS224N)
# * computer vision (CS231N)
# * graphs (CS224W)
