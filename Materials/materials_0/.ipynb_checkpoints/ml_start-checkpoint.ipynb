# %%
"""
pandas
matplotlib

"""

# %%
Image.open("ML_base.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x673>

# %% [markdown]
# ### NumPy Essential Training: 1 Foundations of NumPy

# %% [markdown]
# https://learn.epam.com/detailsPage?id=161a2305-c118-44f3-8a79-499c078bc40d

# %% [markdown]
# * Anaconda
# * Jupyter Notebook
# * NumPy
